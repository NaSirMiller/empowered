# %%
# !ls /home/nasir/Documents/empowered/empowered/models/sql/sql_client.py

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler

from empowered.utils.helpers import get_sql_client
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       2 from sklearn.preprocessing import StandardScaler
# ----> 4 from empowered.utils.helpers import get_sql_client
#
# File ~/anaconda3/envs/empowered/lib/python3.12/site-packages/empowered/utils.py:10
#       6 from typing import Any, Dict, List, Type
#       8 import os
# ---> 10 from empowered.models.sql.sql_client import SQLClient
#      13 @lru_cache(maxsize=4)
#      14 def get_db_client(
#      15     server: str = os.getenv("SQL_SERVER"),
#    (...)     21     ),
#      22 ) -> SQLClient:
#      23     """
#      24     Creates a SQLClient instance for interaction with a SQL database.
#      25
#    (...)     34         SQLClient: _description_
#      35     """
#
# ModuleNotFoundError: No module named 'empowered.models'

# %%
sql_client = get_sql_client()
estimates = sql_client.execute("SELECT * FROM fullCensusEstimate;")

estimates_df = pd.DataFrame(estimates)

estimates_df

# %%
estimates_df.columns
